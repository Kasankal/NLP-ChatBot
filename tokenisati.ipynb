# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Fidel\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Fidel\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\Fidel\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Fidel\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import nltk


from nltk.tokenize import word_tokenize
 
text = "Natural Language Processing is fascinating."

tokens = word_tokenize(text)

print(tokens)
# Out:
# ['Natural', 'Language', 'Processing', 'is', 'fascinating', '.']

# %%
import nltk

nltk.download('stopwords')
nltk.download('punkt')
nltk.download('punkt_tab')

from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

text = "The cat is sitting on the mat"

# Tokenize sentence
tokens = word_tokenize(text)

# Load English stop words
stop_words = set(stopwords.words('english'))

# Remove stop words
filtered_words = []

for word in tokens:
    if word.lower() not in stop_words:
        filtered_words.append(word)

print("Original:", tokens)
print("Filtered:", filtered_words)
# Out:
# Original: ['The', 'cat', 'is', 'sitting', 'on', 'the', 'mat']
# Filtered: ['cat', 'sitting', 'mat']
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Fidel\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Fidel\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Fidel\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
from nltk.util import bigrams
from nltk.tokenize import word_tokenize

text = "Natural Language Processing is fascinating"

tokens = word_tokenize(text)

bigram_list = list(bigrams(tokens))

print("Bigrams:")
print(bigram_list)
# Out:
# Bigrams:
# [('Natural', 'Language'), ('Language', 'Processing'), ('Processing', 'is'), ('is', 'fascinating')]

# %%
from nltk import pos_tag

sentence = "The cat sits on the mat"

tokens = word_tokenize(sentence)

tagged = pos_tag(tokens)

print("\nPOS Tagging:")
print(tagged)
# Out:
# POS Tagging:
# [('The', 'DT'), ('cat', 'NN'), ('sits', 'VBZ'), ('on', 'IN'), ('the', 'DT'), ('mat', 'NN')]

# %%
text = "I love natural language processing"

tokens = word_tokenize(text)

bigram_list = list(bigrams(tokens))

print("\nLanguage Prediction Example:")

for first, second in bigram_list:
    print(f"If word is '{first}', next word might be '{second}'")
# Out:
# Language Prediction Example:
# If word is 'I', next word might be 'love'
# If word is 'love', next word might be 'natural'
# If word is 'natural', next word might be 'language'
# If word is 'language', next word might be 'processing'

# %%
from nltk.corpus import stopwords

text = "Natural Language Processing is very interesting"

tokens = word_tokenize(text)

stop_words = set(stopwords.words('english'))

filtered = []

for word in tokens:
    if word.lower() not in stop_words:
        filtered.append(word)

print("\nSentence Analysis:")
print("Tokens:", tokens)
print("Filtered:", filtered)
print("Word Count:", len(tokens))
# Out:
# Sentence Analysis:
# Tokens: ['Natural', 'Language', 'Processing', 'is', 'very', 'interesting']
# Filtered: ['Natural', 'Language', 'Processing', 'interesting']
# Word Count: 6

# %%
from hmmlearn import hmm
import numpy as np

# Observations
# 0 = No umbrella
# 1 = Umbrella
observations = np.array([[0], [0], [1], [1], [1], [0]])

# Create an HMM with 2 hidden states
model = hmm.CategoricalHMM(n_components=2)

# Initial state probabilities
model.startprob_ = np.array([0.6, 0.4])

# State transition probabilities
model.transmat_ = np.array([
    [0.7, 0.3],  # Sunny -> Sunny/Rainy
    [0.4, 0.6]   # Rainy -> Sunny/Rainy
])

# Emission probabilities
model.emissionprob_ = np.array([
    [0.8, 0.2],  # Sunny: No umbrella, Umbrella
    [0.1, 0.9]   # Rainy: No umbrella, Umbrella
])

# Predict hidden states
hidden_states = model.predict(observations)

print("Observations:", observations.flatten())
print("Predicted hidden states:", hidden_states)
# Out:
# Observations: [0 0 1 1 1 0]
# Predicted hidden states: [0 0 1 1 1 0]

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk import pos_tag

text = "Machine learning improves language processing."

tokens = word_tokenize(text)
tags = pos_tag(tokens)

print(tags)
# Out:
# [('Machine', 'NN'), ('learning', 'VBG'), ('improves', 'NNS'), ('language', 'NN'), ('processing', 'NN'), ('.', '.')]

# %%
import nltk
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

sentence1 = "The student passed the examination"
sentence2 = "The learner succeeded in the exam"

# Combine sentences
sentences = [sentence1, sentence2]

# Convert text to TF-IDF vectors
vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(sentences)

# Compute cosine similarity
similarity = cosine_similarity(tfidf_matrix[0], tfidf_matrix[1])

print("Similarity Score:", similarity[0][0])
# Out:
# Similarity Score: 0.368023208756115

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk import pos_tag

text = "Natural Language Processing helps computers understand language."

# Tokenization
words = word_tokenize(text)
print("Tokens:", words)

# Stopword Removal
stop_words = set(stopwords.words('english'))
filtered = [w for w in words if w.lower() not in stop_words]
print("Filtered:", filtered)

# POS Tagging
pos = pos_tag(filtered)
print("POS Tags:", pos)
# Out:
# Tokens: ['Natural', 'Language', 'Processing', 'helps', 'computers', 'understand', 'language', '.']
# Filtered: ['Natural', 'Language', 'Processing', 'helps', 'computers', 'understand', 'language', '.']
# POS Tags: [('Natural', 'JJ'), ('Language', 'NNP'), ('Processing', 'NNP'), ('helps', 'VBZ'), ('computers', 'NNS'), ('understand', 'JJ'), ('language', 'NN'), ('.', '.')]

# %%
print("Welcome to Student Help Chatbot")

while True:
    user = input("You: ")

    if "hello" in user.lower():
        print("Bot: Hello Student")

    elif "exam" in user.lower():
        print("Bot: CAT 1 starts next week")

    elif "bye" in user.lower():
        print("Bot: Goodbye")
        break

    else:
        print("Bot: I do not understand")
# Out:
# Welcome to Student Help Chatbot
